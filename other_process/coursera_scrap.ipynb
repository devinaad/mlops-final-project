# %%
from bs4 import BeautifulSoup
from urllib.parse import quote_plus
import pandas as pd
import time
import random
import requests

# %%
def scrape_coursera_courses(user_query, max_courses=200):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    }

    encoded_query = quote_plus(user_query)
    courses = []
    page = 1
    per_page = 20

    while len(courses) < max_courses:
        start_index = (page - 1) * per_page
        url = f"https://www.coursera.org/search?query={encoded_query}&start={start_index}&sortBy=BEST_MATCH"

        try:
            response = requests.get(url, headers=headers)
            soup = BeautifulSoup(response.content, 'html.parser')

            course_links = soup.find_all("a", class_="cds-119 cds-113 cds-115 cds-CommonCard-titleLink css-vflzcf cds-142")
            if not course_links:
                break

            for link_tag in course_links:
                if len(courses) >= max_courses:
                    break

                # Title & Link
                title_tag = link_tag.find("h3")
                title = title_tag.get_text(strip=True) if title_tag else None
                href = link_tag.get("href", "")
                full_link = f"https://www.coursera.org{href}" if href.startswith("/") else href

                # Card Container
                card = link_tag.find_parent("li") or link_tag.find_parent("div", class_="cds-ProductCard") or link_tag

                # Organization
                organization = None
                org_container = card.find("p", class_="cds-ProductCard-partnerNames")
                if org_container:
                    organization = org_container.get_text(strip=True)

                # Rating
                rating = None
                rating_tag = card.find("div", {"aria-label": "Rating"})
                if rating_tag:
                    rating = rating_tag.get("aria-valuenow")

                # Metadata
                metadata_text = []
                metadata_div = card.find("div", class_="cds-CommonCard-metadata")
                if metadata_div:
                    p_tags = metadata_div.find_all("p", class_="css-vac8rf")
                    metadata_text = [p.get_text(strip=True) for p in p_tags]
                metadata = ", ".join(metadata_text) if metadata_text else None

                # Skills
                skills = None
                skill_tag = card.find("div", class_="cds-CommonCard-bodyContent")
                if skill_tag:
                    p_tag = skill_tag.find("p", class_="css-vac8rf")
                    if p_tag:
                        skills = p_tag.get_text(strip=True).replace("Skills you'll gain:", "")

                courses.append({
                    "title": title,
                    "link": full_link,
                    "organization": organization,
                    "rating": rating,
                    "metadata": metadata,
                    "skills": skills
                })

            page += 1
            time.sleep(random.uniform(1, 2))

        except Exception as e:
            print(f"Error on page {page}: {e}")
            break

    print(f"Scraping completed: {len(courses)} courses found.")
    return pd.DataFrame(courses)

# %%
job_list = [
    "Data Analyst", "Backend Developer", "QA Tester",
    "Social Media Strategist", "Public Relations", "Tax Consultant",
    "Copywriter", "Financial Analyst", "Auditor",
    "HR Generalist", "Career Counselor", "User Researcher"
]

skill_list = [
    "Python", "Artificial Intelligence", "Excel",
    "Machine Learning", "SQL", "Project Management",
    "Power BI", "Marketing",'java', 'javascript','math',
    'cybersecurity', 'cloud computing', 'acounting', 'ios', 'android', 
    'web development', 'graphic design', 'hr', 'statistics', 'networking',
    'network', 'oop', 'social media', 'seo', 'presentation skills', 'communication skills'
]

# Simpan semua hasil scraping ke dalam satu list
all_dfs = []

# Scrape berdasarkan job title
for job in job_list:
    print(f"Scraping for job: {job}")
    df_job = scrape_coursera_courses(job, max_courses=150)
    df_job['Source'] = job  # menandai asal pencarian
    all_dfs.append(df_job)
    time.sleep(random.uniform(1, 2))  # anti-banned

# Scrape berdasarkan skill
for skill in skill_list:
    print(f"Scraping for skill: {skill}")
    df_skill = scrape_coursera_courses(skill, max_courses=150)
    df_skill['Source'] = skill
    all_dfs.append(df_skill)
    time.sleep(random.uniform(1, 2))

# Gabungkan semua dataframe dan hapus duplikat berdasarkan URL
df_all_course = pd.concat(all_dfs, ignore_index=True)

df_all_course.drop_duplicates(subset=["title", "link"], inplace=True)
# Out:
# Scraping for job: Data Analyst
# Scraping completed: 150 courses found.
# Scraping for job: Backend Developer
# Scraping completed: 150 courses found.
# Scraping for job: QA Tester
# Scraping completed: 150 courses found.
# Scraping for job: Social Media Strategist
# Scraping completed: 150 courses found.
# Scraping for job: Public Relations
# Scraping completed: 150 courses found.
# Scraping for job: Tax Consultant
# Scraping completed: 150 courses found.
# Scraping for job: Copywriter
# Scraping completed: 150 courses found.
# Scraping for job: Financial Analyst
# Scraping completed: 150 courses found.
# Scraping for job: Auditor
# Scraping completed: 150 courses found.
# Scraping for job: HR Generalist
# Scraping completed: 150 courses found.
# Scraping for job: Career Counselor
# Scraping completed: 150 courses found.
# Scraping for job: User Researcher
# Scraping completed: 150 courses found.
# Scraping for skill: Python
# Scraping completed: 150 courses found.
# Scraping for skill: Artificial Intelligence
# Scraping completed: 150 courses found.
# Scraping for skill: Excel
# Scraping completed: 150 courses found.
# Scraping for skill: Machine Learning
# Scraping completed: 150 courses found.
# Scraping for skill: SQL
# Scraping completed: 150 courses found.
# Scraping for skill: Project Management
# Scraping completed: 150 courses found.
# Scraping for skill: Power BI
# Scraping completed: 150 courses found.
# Scraping for skill: Marketing
# Scraping completed: 150 courses found.
# Scraping for skill: java
# Scraping completed: 150 courses found.
# Scraping for skill: javascript
# Scraping completed: 150 courses found.
# Scraping for skill: math
# Scraping completed: 150 courses found.
# Scraping for skill: cybersecurity
# Scraping completed: 150 courses found.
# Scraping for skill: cloud computing
# Scraping completed: 150 courses found.
# Scraping for skill: acounting
# Scraping completed: 150 courses found.
# Scraping for skill: ios
# Scraping completed: 150 courses found.
# Scraping for skill: android
# Scraping completed: 150 courses found.
# Scraping for skill: web development
# Scraping completed: 150 courses found.
# Scraping for skill: graphic design
# Scraping completed: 150 courses found.
# Scraping for skill: hr
# Scraping completed: 150 courses found.
# Scraping for skill: statistics
# Scraping completed: 150 courses found.
# Scraping for skill: networking
# Scraping completed: 150 courses found.
# Scraping for skill: network
# Scraping completed: 150 courses found.
# Scraping for skill: oop
# Scraping completed: 150 courses found.
# Scraping for skill: social media
# Scraping completed: 150 courses found.
# Scraping for skill: seo
# Scraping completed: 150 courses found.
# Scraping for skill: presentation skills
# Scraping completed: 150 courses found.
# Scraping for skill: communication skills
# Scraping completed: 150 courses found.

# %%
print("Total unique courses scraped:", len(df_all_course))
# Out:
# Total unique courses scraped: 445

# %%
df_all_course
# Out:
#                                                   title  \
# 0                                      IBM Data Analyst
# 1                                     Meta Data Analyst
# 2                                 Google Data Analytics
# 3                        Excel Basics for Data Analysis
# 4                       Microsoft Power BI Data Analyst
# ...                                                 ...
# 5704                    Developing Interpersonal Skills
# 5706  Storytelling and influencing: Communicate with...
# 5708                 Communication Skills for Engineers
# 5710               Improve Communication with Genial.ly
# 5721        Communication Skills for University Success
#
#                                                    link  \
# 0     https://www.coursera.org/professional-certific...
# 1     https://www.coursera.org/professional-certific...
# 2     https://www.coursera.org/professional-certific...
# 3     https://www.coursera.org/learn/excel-basics-da...
# 4     https://www.coursera.org/professional-certific...
# ...                                                 ...
# 5704  https://www.coursera.org/learn/interpersonal-s...
# 5706  https://www.coursera.org/learn/communicate-wit...
# 5708  https://www.coursera.org/specializations/leade...
# 5710  https://www.coursera.org/projects/improve-comm...
# 5721  https://www.coursera.org/learn/communication-s...
#
#                   organization rating  \
# 0                          IBM    4.6
# 1                         Meta    4.7
# 2                       Google    4.8
# 3                          IBM    4.8
# 4                    Microsoft    4.6
# ...                        ...    ...
# 5704                       IBM    4.7
# 5706      Macquarie University    4.8
# 5708           Rice University    4.7
# 5710  Coursera Project Network    4.7
# 5721  The University of Sydney    4.8
#
#                                                metadata  \
# 0     Beginner · Professional Certificate · 3 - 6 Mo...
# 1     Beginner · Professional Certificate · 3 - 6 Mo...
# 2     Beginner · Professional Certificate · 3 - 6 Mo...
# 3                      Beginner · Course · 1 - 3 Months
# 4     Beginner · Professional Certificate · 3 - 6 Mo...
# ...                                                 ...
# 5704                    Beginner · Course · 1 - 4 Weeks
# 5706                      Mixed · Course · 1 - 3 Months
# 5708           Beginner · Specialization · 3 - 6 Months
# 5710      Beginner · Guided Project · Less Than 2 Hours
# 5721                   Beginner · Course · 1 - 3 Months
#
#                                                  skills                Source
# 0     Skills you'll gain:Data Storytelling, Dashboar...          Data Analyst
# 1     Skills you'll gain:Data Storytelling, Business...          Data Analyst
# 2     Skills you'll gain:Data Storytelling, Rmarkdow...          Data Analyst
# 3     Skills you'll gain:Excel Formulas, Microsoft E...          Data Analyst
# 4     Skills you'll gain:Power BI, Microsoft Excel, ...          Data Analyst
# ...                                                 ...                   ...
# 5704  Skills you'll gain:Active Listening, Interpers...  communication skills
# 5706  Skills you'll gain:Overcoming Objections, Infl...  communication skills
# 5708  Skills you'll gain:Proposal Writing, Oral Expr...  communication skills
# 5710  Skills you'll gain:Train The Trainer, Virtual ...  communication skills
# 5721  Skills you'll gain:Editing, Public Speaking, P...  communication skills
#
# [445 rows x 7 columns]

# %%
# Pisahkan berdasarkan tanda pemisah ' · '
metadata_split = df_all_course['metadata'].str.split(' · ', expand=True)

# Buat kolom baru dari hasil pemisahan
df_all_course['difficulty'] = metadata_split[0]
df_all_course['duration'] = metadata_split[2] 
df_all_course.drop(columns=['metadata'], inplace=True)

# Hapus "Skills you'll gain:" dari kolom 'skills'
df_all_course['skills'] = df_all_course['skills'].str.replace("Skills you'll gain:", "", regex=False)

# (Opsional) Hilangkan spasi berlebih di awal/akhir
df_all_course['skills'] = df_all_course['skills'].str.strip()

# %%
df_all_course.drop(columns=['Source'], inplace=True)
df_all_course

# %%
import pandas as pd
data = pd.read_csv('coursera_courses.csv')
data.drop(columns=['Source'], inplace=True)
data
# Out:
#                                                  title  \
# 0                                     IBM Data Analyst
# 1                                    Meta Data Analyst
# 2                                Google Data Analytics
# 3                       Excel Basics for Data Analysis
# 4                      Microsoft Power BI Data Analyst
# ..                                                 ...
# 440                    Developing Interpersonal Skills
# 441  Storytelling and influencing: Communicate with...
# 442                 Communication Skills for Engineers
# 443               Improve Communication with Genial.ly
# 444        Communication Skills for University Success
#
#                                                   link  \
# 0    https://www.coursera.org/professional-certific...
# 1    https://www.coursera.org/professional-certific...
# 2    https://www.coursera.org/professional-certific...
# 3    https://www.coursera.org/learn/excel-basics-da...
# 4    https://www.coursera.org/professional-certific...
# ..                                                 ...
# 440  https://www.coursera.org/learn/interpersonal-s...
# 441  https://www.coursera.org/learn/communicate-wit...
# 442  https://www.coursera.org/specializations/leade...
# 443  https://www.coursera.org/projects/improve-comm...
# 444  https://www.coursera.org/learn/communication-s...
#
#                  organization  rating  \
# 0                         IBM     4.6
# 1                        Meta     4.7
# 2                      Google     4.8
# 3                         IBM     4.8
# 4                   Microsoft     4.6
# ..                        ...     ...
# 440                       IBM     4.7
# 441      Macquarie University     4.8
# 442           Rice University     4.7
# 443  Coursera Project Network     4.7
# 444  The University of Sydney     4.8
#
#                                                 skills difficulty  \
# 0    Data Storytelling, Dashboard, Data Visualizati...   Beginner
# 1    Data Storytelling, Business Metrics, Key Perfo...   Beginner
# 2    Data Storytelling, Rmarkdown, Data Literacy, D...   Beginner
# 3    Excel Formulas, Microsoft Excel, Data Cleansin...   Beginner
# 4    Power BI, Microsoft Excel, Data Analysis, Data...   Beginner
# ..                                                 ...        ...
# 440  Active Listening, Interpersonal Communications...   Beginner
# 441  Overcoming Objections, Influencing, Persuasive...      Mixed
# 442  Proposal Writing, Oral Expression, Presentatio...   Beginner
# 443  Train The Trainer, Virtual Environment, Techni...   Beginner
# 444  Editing, Public Speaking, Proofreading, Resear...   Beginner
#
#               duration
# 0         3 - 6 Months
# 1         3 - 6 Months
# 2         3 - 6 Months
# 3         1 - 3 Months
# 4         3 - 6 Months
# ..                 ...
# 440        1 - 4 Weeks
# 441       1 - 3 Months
# 442       3 - 6 Months
# 443  Less Than 2 Hours
# 444       1 - 3 Months
#
# [445 rows x 7 columns]

# %%
data.to_csv("coursera_courses.csv", index=False)

# %%
import pandas as pd
data = pd.read_csv('job_title_des.csv')
data["Job Title"].value_counts()
# Out:
# Job Title
# Backend Developer          169
# JavaScript Developer       166
# Java Developer             161
# Node js developer          160
# Software Engineer          160
# iOS Developer              159
# PHP Developer              156
# Flutter Developer          155
# DevOps Engineer            155
# Machine Learning           152
# Django Developer           152
# Network Administrator      145
# Database Administrator     139
# Full Stack Developer       138
# Wordpress Developer        132
# Copywriter                  31
# Social Media Strategist     28
# User Researcher             27
# Public Relations            24
# HR Generalist               22
# Tax Consultant              21
# Data Analyst                19
# Financial Analyst           18
# Auditor                     15
# QA Tester                   12
# Career Counselor            11
# Name: count, dtype: int64
